# %%
# %%writefile test.cpp
# #include <stdio.h>
# int main(void)
# {
#   printf("hello, world to you\n");
#   return 0;
# }
# Out:
# Overwriting test.cpp

# %%
# Out:
# Overwriting bisection.cpp

# %%
# !ls test.cpp
# chek files
# Out:
# test.cpp

# %%
# !rm test.c
#remove files

# %%
# %%shell
# g++ test.cpp -o testexe
# ./testexe
# Out:
# test.cpp:9:6: warning: ISO C++ forbids declaration of ‘main’ with no type [-Wreturn-type]
#     9 | main()
#       |      ^
# loop=1, x=-2.148148e+00, f(x)=7.319753e+01
# loop=2, x=-8.564270e-01, f(x)=1.501689e+01
# loop=3, x=-4.070305e-01, f(x)=1.817615e+00
# loop=4, x=-3.352634e-01, f(x)=4.635473e-02
# loop=5, x=-3.333347e-01, f(x)=3.347740e-05
# loop=6, x=-3.333333e-01, f(x)=1.751221e-11
# 1th root=-3.333333e-01
# loop=1, x=3.677778e+00, f(x)=4.853444e+01
# loop=2, x=2.670839e+00, f(x)=9.125330e+00
# loop=3, x=2.367421e+00, f(x)=8.285627e-01
# loop=4, x=2.333758e+00, f(x)=1.019867e-02
# loop=5, x=2.333333e+00, f(x)=1.624167e-06
# loop=6, x=2.333333e+00, f(x)=3.552714e-14
# 2th root=2.333333e+00
# sh: 1: pause: not found
